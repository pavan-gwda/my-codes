# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to reference the solutions as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often throughout the course, we will switch to using pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.show()

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
plt.plot(x,y)
plt.xlim(0,100)
plt.ylim(0,200)
plt.xticks(np.arange(0,101,20))
plt.yticks(np.arange(0,201,50))
plt.xlabel('x')
plt.ylabel('y')
plt.title('title')
# Out:
# Text(0.5,1,'title')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
print('hi')
# Out:
# hi

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.2,.2])
plt.xticks(np.arange(0,1,0.2))
plt.yticks(np.arange(0,1,0.2))
# Out:
# ([<matplotlib.axis.YTick at 0x609d50>,
#   <matplotlib.axis.YTick at 0x600f10>,
#   <matplotlib.axis.YTick at 0x622b10>,
#   <matplotlib.axis.YTick at 0x62a1b0>,
#   <matplotlib.axis.YTick at 0x62a570>],
#  <a list of 5 Text yticklabel objects>)

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
plt.plot(x,y,'r-')
plt.xlim(0,100)
plt.ylim(0,200)
plt.xticks(np.arange(0,101,20))
plt.yticks(np.arange(0,201,50))
ax2=fig.add_axes([0.2,0.5,.2,.2])
plt.xticks(np.arange(0,101,20))
plt.yticks(np.arange(0,201,50))
plt.plot(x,y,'r-')

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.4,.4])
plt.xticks(np.arange(0,1,0.2))
plt.yticks(np.arange(0,1,0.2))
# Out:
# ([<matplotlib.axis.YTick at 0x7df61d0>,
#   <matplotlib.axis.YTick at 0x7df6710>,
#   <matplotlib.axis.YTick at 0x7df6790>,
#   <matplotlib.axis.YTick at 0x7f51170>,
#   <matplotlib.axis.YTick at 0x7f51c50>],
#  <a list of 5 Text yticklabel objects>)

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
plt.plot(x,z)
plt.xlabel('X')
plt.ylabel('Z')
plt.ylim(0,10000)
plt.xlim(0,100)
ax2=fig.add_axes([0.2,0.5,.4,.4])
plt.plot(x,y)
plt.title('zoom')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(20,22)
plt.ylim(30,50)
# Out:
# (30, 50)

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig=plt.figure()
fig.add_subplot(1,2,1)
fig.add_subplot(1,2,2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig=plt.figure()
fig.add_subplot(1,2,1)
plt.plot(x,y,'b--',linewidth=4)
plt.yticks(np.arange(0,201,50))
plt.xlim(0,100)
plt.ylim(0,200)
fig.add_subplot(1,2,2)
plt.plot(x,z,'r-',linewidth=4)
plt.xlim(0,100)
plt.ylim(0,10000)
# Out:
# (0, 10000)

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig=plt.figure(figsize=(15,2))
fig.add_subplot(1,2,1)
plt.plot(x,y,'b-',linewidth=4)
plt.yticks(np.arange(0,201,50))
plt.xlim(0,100)
plt.ylim(0,200)
fig.add_subplot(1,2,2)
plt.plot(x,z,'r--',linewidth=4)
plt.xlim(0,100)
plt.ylim(0,10000)
# Out:
# (0, 10000)

# %% [markdown]
# # Great Job!
